# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing

# %%
train = pd.read_csv('new_train2.csv')
train
# Out:
#        age           job   marital            education  default housing loan  \
# 0       49   blue-collar   married             basic.9y  unknown      no   no
# 1       37  entrepreneur   married    university.degree       no      no   no
# 2       55       retired   married             basic.4y       no      no   no
# 3       36        admin.   married    university.degree       no     yes   no
# 4       55       retired  divorced    university.degree       no      no   no
# ...    ...           ...       ...                  ...      ...     ...  ...
# 32949   35        admin.   married    university.degree       no      no  yes
# 32950   33        admin.    single          high.school       no     yes   no
# 32951   50      services   married          high.school       no     yes   no
# 32952   26       student    single          high.school       no      no   no
# 32953   28      services    single  professional.course       no     yes   no
#
#          contact month day_of_week  duration  campaign     poutcome    y
# 0       cellular   nov         wed       227         4  nonexistent   no
# 1      telephone   nov         wed       202         2      failure   no
# 2       cellular   jul         mon       550         1  nonexistent  yes
# 3      telephone   may         mon       120         2  nonexistent   no
# 4       cellular   jun         tue       368         2  nonexistent   no
# ...          ...   ...         ...       ...       ...          ...  ...
# 32949  telephone   jun         tue       544         3  nonexistent   no
# 32950   cellular   jul         tue       498         5  nonexistent   no
# 32951   cellular   jul         fri        60         5  nonexistent   no
# 32952   cellular   jun         thu       400         1  nonexistent  yes
# 32953   cellular   mar         fri       169         3      failure   no
#
# [32954 rows x 14 columns]

# %%
train.isnull().sum()
# Out:
# age            0
# job            0
# marital        0
# education      0
# default        0
# housing        0
# loan           0
# contact        0
# month          0
# day_of_week    0
# duration       0
# campaign       0
# poutcome       0
# y              0
# dtype: int64

# %%
train['y']=train['y'].eq('yes').mul(1)
result = train['y']
result
# Out:
# 0        0
# 1        0
# 2        1
# 3        0
# 4        0
#         ..
# 32949    0
# 32950    0
# 32951    0
# 32952    1
# 32953    0
# Name: y, Length: 32954, dtype: int64

# %%
plt.hist(result)
yes_count = len([item for item in result if item == 1])
no_count = len([item for item in result if item == 0])
count = [yes_count, no_count]
plt.pie(count, labels = ['yes','no'],autopct='%1.2f%%')
plt.title("Result distribution")
# Out:
# Text(0.5, 1.0, 'Result distribution')

# %%
plt.hist(result)
yes_count = len([item for item in result if item == 1])
no_count = len([item for item in result if item == 0])
count = [yes_count, no_count]
plt.pie(count, labels = ['yes','no'],autopct='%1.2f%%')
plt.title("Result distribution")
# Out:
# Text(0.5, 1.0, 'Result distribution')

# %% [markdown]
# Education analysis

# %%
train['y_str'] = train['y'].astype(str)
f,ax=plt.subplots(1,2,figsize=(26,8))
sns.countplot(y='education',data=train, ax=ax[0])
sns.countplot(y='education',hue = 'y_str', data = train, ax = ax[1])
train.groupby(['education'])['y'].mean().to_frame().style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_a7650_row0_col0 {
#   background-color: #c1e066;
#   color: #000000;
# }
# #T_a7650_row1_col0 {
#   background-color: #eff766;
#   color: #000000;
# }
# #T_a7650_row2_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_a7650_row3_col0 {
#   background-color: #b8dc66;
#   color: #000000;
# }
# #T_a7650_row4_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_a7650_row5_col0 {
#   background-color: #acd666;
#   color: #000000;
# }
# #T_a7650_row6_col0 {
#   background-color: #71b866;
#   color: #f1f1f1;
# }
# #T_a7650_row7_col0 {
#   background-color: #5aac66;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a7650">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7650_level0_col0" class="col_heading level0 col0" >y</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >education</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7650_level0_row0" class="row_heading level0 row0" >basic.4y</th>
#       <td id="T_a7650_row0_col0" class="data row0 col0" >0.103552</td>
#     </tr>
#     <tr>
#       <th id="T_a7650_level0_row1" class="row_heading level0 row1" >basic.6y</th>
#       <td id="T_a7650_row1_col0" class="data row1 col0" >0.083646</td>
#     </tr>
#     <tr>
#       <th id="T_a7650_level0_row2" class="row_heading level0 row2" >basic.9y</th>
#       <td id="T_a7650_row2_col0" class="data row2 col0" >0.076461</td>
#     </tr>
#     <tr>
#       <th id="T_a7650_level0_row3" class="row_heading level0 row3" >high.school</th>
#       <td id="T_a7650_row3_col0" class="data row3 col0" >0.107383</td>
#     </tr>
#     <tr>
#       <th id="T_a7650_level0_row4" class="row_heading level0 row4" >illiterate</th>
#       <td id="T_a7650_row4_col0" class="data row4 col0" >0.187500</td>
#     </tr>
#     <tr>
#       <th id="T_a7650_level0_row5" class="row_heading level0 row5" >professional.course</th>
#       <td id="T_a7650_row5_col0" class="data row5 col0" >0.112807</td>
#     </tr>
#     <tr>
#       <th id="T_a7650_level0_row6" class="row_heading level0 row6" >university.degree</th>
#       <td id="T_a7650_row6_col0" class="data row6 col0" >0.138147</td>
#     </tr>
#     <tr>
#       <th id="T_a7650_level0_row7" class="row_heading level0 row7" >unknown</th>
#       <td id="T_a7650_row7_col0" class="data row7 col0" >0.148175</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Job Analysis

# %%
f,ax=plt.subplots(1,2,figsize=(26,8))
sns.countplot(y='job',data=train, ax=ax[0])
sns.countplot(y='job',hue = 'y_str', data = train, ax = ax[1])
plt.show()
train.groupby(['job'])['y'].mean().to_frame().style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_e5d72_row0_col0 {
#   background-color: #bfdf66;
#   color: #000000;
# }
# #T_e5d72_row1_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_e5d72_row2_col0 {
#   background-color: #edf666;
#   color: #000000;
# }
# #T_e5d72_row3_col0 {
#   background-color: #deee66;
#   color: #000000;
# }
# #T_e5d72_row4_col0 {
#   background-color: #cee666;
#   color: #000000;
# }
# #T_e5d72_row5_col0 {
#   background-color: #379b66;
#   color: #f1f1f1;
# }
# #T_e5d72_row6_col0, #T_e5d72_row9_col0 {
#   background-color: #d5ea66;
#   color: #000000;
# }
# #T_e5d72_row7_col0 {
#   background-color: #f4fa66;
#   color: #000000;
# }
# #T_e5d72_row8_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_e5d72_row10_col0 {
#   background-color: #add666;
#   color: #000000;
# }
# #T_e5d72_row11_col0 {
#   background-color: #c4e266;
#   color: #000000;
# }
# </style>
# <table id="T_e5d72">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e5d72_level0_col0" class="col_heading level0 col0" >y</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >job</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5d72_level0_row0" class="row_heading level0 row0" >admin.</th>
#       <td id="T_e5d72_row0_col0" class="data row0 col0" >0.128683</td>
#     </tr>
#     <tr>
#       <th id="T_e5d72_level0_row1" class="row_heading level0 row1" >blue-collar</th>
#       <td id="T_e5d72_row1_col0" class="data row1 col0" >0.069211</td>
#     </tr>
#     <tr>
#       <th id="T_e5d72_level0_row2" class="row_heading level0 row2" >entrepreneur</th>
#       <td id="T_e5d72_row2_col0" class="data row2 col0" >0.086207</td>
#     </tr>
#     <tr>
#       <th id="T_e5d72_level0_row3" class="row_heading level0 row3" >housemaid</th>
#       <td id="T_e5d72_row3_col0" class="data row3 col0" >0.100585</td>
#     </tr>
#     <tr>
#       <th id="T_e5d72_level0_row4" class="row_heading level0 row4" >management</th>
#       <td id="T_e5d72_row4_col0" class="data row4 col0" >0.114712</td>
#     </tr>
#     <tr>
#       <th id="T_e5d72_level0_row5" class="row_heading level0 row5" >retired</th>
#       <td id="T_e5d72_row5_col0" class="data row5 col0" >0.254758</td>
#     </tr>
#     <tr>
#       <th id="T_e5d72_level0_row6" class="row_heading level0 row6" >self-employed</th>
#       <td id="T_e5d72_row6_col0" class="data row6 col0" >0.108280</td>
#     </tr>
#     <tr>
#       <th id="T_e5d72_level0_row7" class="row_heading level0 row7" >services</th>
#       <td id="T_e5d72_row7_col0" class="data row7 col0" >0.079425</td>
#     </tr>
#     <tr>
#       <th id="T_e5d72_level0_row8" class="row_heading level0 row8" >student</th>
#       <td id="T_e5d72_row8_col0" class="data row8 col0" >0.306180</td>
#     </tr>
#     <tr>
#       <th id="T_e5d72_level0_row9" class="row_heading level0 row9" >technician</th>
#       <td id="T_e5d72_row9_col0" class="data row9 col0" >0.108333</td>
#     </tr>
#     <tr>
#       <th id="T_e5d72_level0_row10" class="row_heading level0 row10" >unemployed</th>
#       <td id="T_e5d72_row10_col0" class="data row10 col0" >0.145363</td>
#     </tr>
#     <tr>
#       <th id="T_e5d72_level0_row11" class="row_heading level0 row11" >unknown</th>
#       <td id="T_e5d72_row11_col0" class="data row11 col0" >0.124528</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Default Analysis

# %%
f,ax=plt.subplots(1,2,figsize=(26,8))
sns.countplot(y='default',data=train, ax=ax[0])
sns.countplot(y='default',hue = 'y_str', data = train, ax = ax[1])
plt.show()
train.groupby(['default'])['y'].mean().to_frame().style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_8c2df_row0_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_8c2df_row1_col0 {
#   background-color: #98cc66;
#   color: #000000;
# }
# #T_8c2df_row2_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# </style>
# <table id="T_8c2df">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8c2df_level0_col0" class="col_heading level0 col0" >y</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >default</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c2df_level0_row0" class="row_heading level0 row0" >no</th>
#       <td id="T_8c2df_row0_col0" class="data row0 col0" >0.128869</td>
#     </tr>
#     <tr>
#       <th id="T_8c2df_level0_row1" class="row_heading level0 row1" >unknown</th>
#       <td id="T_8c2df_row1_col0" class="data row1 col0" >0.052017</td>
#     </tr>
#     <tr>
#       <th id="T_8c2df_level0_row2" class="row_heading level0 row2" >yes</th>
#       <td id="T_8c2df_row2_col0" class="data row2 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Housing Analysis

# %%
f,ax=plt.subplots(1,2,figsize=(26,8))
sns.countplot(y='housing',data=train, ax=ax[0])
sns.countplot(y='housing',hue = 'y_str', data = train, ax = ax[1])
train.groupby(['housing'])['y'].mean().to_frame().style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_b0c29_row0_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_b0c29_row1_col0 {
#   background-color: #66b266;
#   color: #f1f1f1;
# }
# #T_b0c29_row2_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b0c29">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b0c29_level0_col0" class="col_heading level0 col0" >y</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >housing</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b0c29_level0_row0" class="row_heading level0 row0" >no</th>
#       <td id="T_b0c29_row0_col0" class="data row0 col0" >0.109322</td>
#     </tr>
#     <tr>
#       <th id="T_b0c29_level0_row1" class="row_heading level0 row1" >unknown</th>
#       <td id="T_b0c29_row1_col0" class="data row1 col0" >0.113065</td>
#     </tr>
#     <tr>
#       <th id="T_b0c29_level0_row2" class="row_heading level0 row2" >yes</th>
#       <td id="T_b0c29_row2_col0" class="data row2 col0" >0.115547</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Loan Analysis

# %%
f,ax=plt.subplots(1,2,figsize=(26,8))
sns.countplot(y='loan',data=train, ax=ax[0])
sns.countplot(y='loan',hue = 'y_str', data = train, ax = ax[1])
train.groupby(['loan'])['y'].count().to_frame().style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_bc689_row0_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_bc689_row1_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_bc689_row2_col0 {
#   background-color: #d6eb66;
#   color: #000000;
# }
# </style>
# <table id="T_bc689">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc689_level0_col0" class="col_heading level0 col0" >y</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >loan</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc689_level0_row0" class="row_heading level0 row0" >no</th>
#       <td id="T_bc689_row0_col0" class="data row0 col0" >27135</td>
#     </tr>
#     <tr>
#       <th id="T_bc689_level0_row1" class="row_heading level0 row1" >unknown</th>
#       <td id="T_bc689_row1_col0" class="data row1 col0" >796</td>
#     </tr>
#     <tr>
#       <th id="T_bc689_level0_row2" class="row_heading level0 row2" >yes</th>
#       <td id="T_bc689_row2_col0" class="data row2 col0" >5023</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Marital Analysis

# %%
f,ax=plt.subplots(1,2,figsize=(26,8))
sns.countplot(y='marital',data=train, ax=ax[0])
sns.countplot(y='marital',hue = 'y_str', data = train, ax = ax[1])
train.groupby(['marital'])['y'].mean().to_frame().style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_fcb65_row0_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_fcb65_row1_col0 {
#   background-color: #fefe66;
#   color: #000000;
# }
# #T_fcb65_row2_col0 {
#   background-color: #67b366;
#   color: #f1f1f1;
# }
# #T_fcb65_row3_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fcb65">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fcb65_level0_col0" class="col_heading level0 col0" >y</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >marital</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fcb65_level0_row0" class="row_heading level0 row0" >divorced</th>
#       <td id="T_fcb65_row0_col0" class="data row0 col0" >0.100952</td>
#     </tr>
#     <tr>
#       <th id="T_fcb65_level0_row1" class="row_heading level0 row1" >married</th>
#       <td id="T_fcb65_row1_col0" class="data row1 col0" >0.101233</td>
#     </tr>
#     <tr>
#       <th id="T_fcb65_level0_row2" class="row_heading level0 row2" >single</th>
#       <td id="T_fcb65_row2_col0" class="data row2 col0" >0.141577</td>
#     </tr>
#     <tr>
#       <th id="T_fcb65_level0_row3" class="row_heading level0 row3" >unknown</th>
#       <td id="T_fcb65_row3_col0" class="data row3 col0" >0.169231</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Age analysis

# %%
sns.displot(train.age,bins=20)

train['age_range']=pd.qcut(train['age'],10, duplicates='drop')
train.groupby(['age_range'])['y'].mean().to_frame().style.background_gradient(cmap='summer_r')
# Out:
# /Users/zwenab/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /var/folders/m_/trd8d3l54qnfg_h7zr0mpfyc0000gn/T/ipykernel_82149/1915786131.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   train.groupby(['age_range'])['y'].mean().to_frame().style.background_gradient(cmap='summer_r')
# <style type="text/css">
# #T_a2e35_row0_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_a2e35_row1_col0 {
#   background-color: #95ca66;
#   color: #000000;
# }
# #T_a2e35_row2_col0 {
#   background-color: #bfdf66;
#   color: #000000;
# }
# #T_a2e35_row3_col0 {
#   background-color: #c3e166;
#   color: #000000;
# }
# #T_a2e35_row4_col0 {
#   background-color: #dbed66;
#   color: #000000;
# }
# #T_a2e35_row5_col0 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_a2e35_row6_col0 {
#   background-color: #fafc66;
#   color: #000000;
# }
# #T_a2e35_row7_col0 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_a2e35_row8_col0 {
#   background-color: #55aa66;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a2e35">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2e35_level0_col0" class="col_heading level0 col0" >y</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >age_range</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2e35_level0_row0" class="row_heading level0 row0" >(25.999, 28.0]</th>
#       <td id="T_a2e35_row0_col0" class="data row0 col0" >0.176799</td>
#     </tr>
#     <tr>
#       <th id="T_a2e35_level0_row1" class="row_heading level0 row1" >(28.0, 31.0]</th>
#       <td id="T_a2e35_row1_col0" class="data row1 col0" >0.119158</td>
#     </tr>
#     <tr>
#       <th id="T_a2e35_level0_row2" class="row_heading level0 row2" >(31.0, 33.0]</th>
#       <td id="T_a2e35_row2_col0" class="data row2 col0" >0.103153</td>
#     </tr>
#     <tr>
#       <th id="T_a2e35_level0_row3" class="row_heading level0 row3" >(33.0, 35.0]</th>
#       <td id="T_a2e35_row3_col0" class="data row3 col0" >0.101737</td>
#     </tr>
#     <tr>
#       <th id="T_a2e35_level0_row4" class="row_heading level0 row4" >(35.0, 38.0]</th>
#       <td id="T_a2e35_row4_col0" class="data row4 col0" >0.092137</td>
#     </tr>
#     <tr>
#       <th id="T_a2e35_level0_row5" class="row_heading level0 row5" >(38.0, 41.0]</th>
#       <td id="T_a2e35_row5_col0" class="data row5 col0" >0.081107</td>
#     </tr>
#     <tr>
#       <th id="T_a2e35_level0_row6" class="row_heading level0 row6" >(41.0, 45.0]</th>
#       <td id="T_a2e35_row6_col0" class="data row6 col0" >0.080547</td>
#     </tr>
#     <tr>
#       <th id="T_a2e35_level0_row7" class="row_heading level0 row7" >(45.0, 49.0]</th>
#       <td id="T_a2e35_row7_col0" class="data row7 col0" >0.078275</td>
#     </tr>
#     <tr>
#       <th id="T_a2e35_level0_row8" class="row_heading level0 row8" >(49.0, 55.0]</th>
#       <td id="T_a2e35_row8_col0" class="data row8 col0" >0.143941</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Label Encoding

# %%
le = preprocessing.LabelEncoder()
le.fit(train.education.unique())
education_encoded = le.transform(train.education).tolist()

le = preprocessing.LabelEncoder()
le.fit(train.job.unique())
job_encoded = le.transform(train.job).tolist()

le = preprocessing.LabelEncoder()
le.fit(train.default.unique())
default_encoded = le.transform(train.default).tolist()

le = preprocessing.LabelEncoder()
le.fit(train.housing.unique())
housing_encoded = le.transform(train.housing).tolist()

le = preprocessing.LabelEncoder()
le.fit(train.loan.unique())
loan_encoded = le.transform(train.loan).tolist()


le = preprocessing.LabelEncoder()
le.fit(train.marital.unique())
marital_encoded = le.transform(train.marital).tolist()
print(le.transform(['single','married','divorced']))

age_encoded = train.age.tolist()

duration_encoded = train.duration.tolist()
y_encoded = train.y.tolist()

data = {'age':age_encoded, 'education':education_encoded, 'job':job_encoded, 'default':default_encoded,'housing':housing_encoded,'loan':loan_encoded,'marital':marital_encoded,'duration':duration_encoded,'result':y_encoded}
df = pd.DataFrame(data)
sns.heatmap(df.corr(),annot=True,cmap='RdYlGn',linewidths=0.2,annot_kws={'size':13})
fig=plt.gcf()
fig.set_size_inches(10,9)
# Out:
# [2 1 0]
